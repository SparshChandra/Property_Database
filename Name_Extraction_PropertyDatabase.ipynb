# %%
import pandas

# %%
import pandas as pd
df = pd.read_csv(r'2515_WILDWOOD_abs_Sheet1.csv')
df
# Out:
#     APN/PIN/Tax 1  APN/PIN/Tax 2  APN/PIN/Tax 3   FIPS  Census Tract  \
# 0           25179        1059591            NaN  37045      950700.0
# 1           25500        1193927            NaN  37045           NaN
# 2           25188        1333461            NaN  37045      950701.0
# 3           25168       19697951            NaN  37045      950700.0
# 4           25170       13599701            NaN  37045      950700.0
# 5           25504        1339586            NaN  37045      950700.0
# 6           25164        1319912            NaN  37045      950700.0
# 7           25209        1326403            NaN  37045      950700.0
# 8           25514        1008655            NaN  37045      950700.0
# 9           70245        1220624            NaN  37045      950700.0
# 10          25207        1220624            NaN  37045      950700.0
# 11          25208        6877001            NaN  37045      950700.0
# 12          25186        1078517            NaN  37045      950701.0
# ...

# %%
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df
# Out:
#     APN/PIN/Tax 1  APN/PIN/Tax 2  APN/PIN/Tax 3   FIPS  Census Tract  \
# 0           25179        1059591            NaN  37045      950700.0
# 1           25500        1193927            NaN  37045           NaN
# 2           25188        1333461            NaN  37045      950701.0
# 3           25168       19697951            NaN  37045      950700.0
# 4           25170       13599701            NaN  37045      950700.0
# 5           25504        1339586            NaN  37045      950700.0
# 6           25164        1319912            NaN  37045      950700.0
# 7           25209        1326403            NaN  37045      950700.0
# 8           25514        1008655            NaN  37045      950700.0
# 9           70245        1220624            NaN  37045      950700.0
# 10          25207        1220624            NaN  37045      950700.0
# 11          25208        6877001            NaN  37045      950700.0
# 12          25186        1078517            NaN  37045      950701.0
# ...

# %%
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers']]
new
# Out:
#            owner_Full_Name owner_email_Addresses  \
# 0       JAMES LARRY BROOKS                   NaN
# 1        GREENE ANN BAILEY                   NaN
# 2           MARSHA H WHITE                   NaN
# 3           MARION B SHANK                   NaN
# 4         THREASA LONGMIRE                   NaN
# 5     LANE AUSTIN CROTHERS                   NaN
# 6           BERNICE DACONS                   NaN
# 7       YVETTE DANA CARTER                   NaN
# 8             RUTH STANTON                   NaN
# 9           LARRY J BROOKS                   NaN
# 10          LARRY J BROOKS                   NaN
# 11            JIMMY ELMORE                   NaN
# 12        VIRGINIA B MCRAE                   NaN
# 13    HORD INVESTMENTS LLC                   NaN
# 14       WAYNE DAVID ALLEN                   NaN
# 15         BRENDA M HAYNES                   NaN
# 16      KIMBERLY D SUMMERS                   NaN
# 17          MARION B MASON       AIPMYLO@MSN.COM
# ...

# %%
# Out:
# Empty DataFrame
# ...

# %%
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#      owner_Full_Name owner_email_Addresses  \
# 17    MARION B MASON       AIPMYLO@MSN.COM
# 19  BELINDA C GEDDIS   ZUCK.IE@HOTMAIL.COM
#
#                                owner_Phone_Numbers
# 17  7048191200 DNC, 7048655208 DNC, 7048668244 DNC
# 19                      7202429003, 7202768787 DNC
