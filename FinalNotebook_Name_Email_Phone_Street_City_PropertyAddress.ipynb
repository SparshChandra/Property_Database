# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2515_WILDWOOD_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#      owner_Full_Name owner_email_Addresses  \
# 17    MARION B MASON       AIPMYLO@MSN.COM
# 19  BELINDA C GEDDIS   ZUCK.IE@HOTMAIL.COM
#
#                                owner_Phone_Numbers ownertwo_Full_Name  \
# 17  7048191200 DNC, 7048655208 DNC, 7048668244 DNC  LOUIS JAMES MASON
# 19                      7202429003, 7202768787 DNC                NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers             street  \
# 17                       NaN                     NaN      3037 SALEM DR
# 19                       NaN                     NaN  8295 S MARION WAY
#
#       City        City State State  Zipcode Relationship_to_Property
# 17  SHELBY    GASTONIA    NC    NC    28052         2518 WILDWOOD DR
# 19  SHELBY  CENTENNIAL    NC    CO    80122         2515 WILDWOOD DR

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3015_PLEASANT_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3431_BOONE_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#        owner_Full_Name  owner_email_Addresses  owner_Phone_Numbers  \
# 10  JAMES null WATKINS  JAMES302139@GMAIL.COM         9.105271e+09
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 10    SHERRIL WATKINS                       NaN                     NaN
#
#                  street          City          City State State  Zipcode  \
# 10  5444 SUMMER DUCK RD  FAYETTEVILLE  FAYETTEVILLE    NC    NC    28314
#
#    Relationship_to_Property
# 10           3530 BOONE TRL

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'10910_N_19TH_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#     owner_Full_Name     owner_email_Addresses             owner_Phone_Numbers  \
# 4    APRIL M HENDRY  YOURDIRTYMOMMA@YAHOO.COM          8133004410, 8135589315
# 13  DIANE M SPARROW  DIANESPARROW@VERIZON.NET  8135082600 DNC, 8139715503 DNC
# 18    DAYSI L NUNEZ       DLNUNEZ18@GMAIL.COM                      8139688249
#
#         ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 4                      NaN                       NaN                     NaN
# 13  EDMOND CHARLES MARKHAM                       NaN                     NaN
# 18             ALLAN NUNEZ                       NaN                     NaN
#
#                    street   City     City State State  Zipcode  \
# 4   309 FOREST BREEZE AVE  TAMPA  BRANDON    FL    FL    33511
# 13           PO BOX 82908  TAMPA    TAMPA    FL    FL    33682
# 18     10818 ROUNDVIEW LN  TAMPA    TAMPA    FL    FL    33624
#
#    Relationship_to_Property
# 4          1817 E 109TH AVE
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'330_BROADWAY_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name   owner_email_Addresses  \
# 2  YVONNE C THANEM     YTHANEM@HOTMAIL.COM
# 7    GWEN M WASDEN  GOTFROGS1010@GMAIL.COM
#
#                       owner_Phone_Numbers ownertwo_Full_Name  \
# 2  2067358589, 3342649674 DNC, 4258641860                NaN
# 7          3342217996 DNC, 3342657330 DNC                NaN
#
#    ownertwo_email_Addresses  ownertwo_Phone_Numbers              street  \
# 2                       NaN                     NaN        2072 AMOS ST
# 7                       NaN                     NaN  781 GREEN RIDGE RD
#
#          City        City State State  Zipcode Relationship_to_Property
# 2  MONTGOMERY  MONTGOMERY    AL    AL    36107          322 BROADWAY ST
# 7  MONTGOMERY  MONTGOMERY    AL    AL    36109          535 BROADWAY ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'4208_3RD_AVENUE_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'Carolina_St_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'15507_PEBBLE_LAKE_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#      owner_Full_Name         owner_email_Addresses  \
# 4    ANGELA J CAMBLE  ANGELAMESTANZA21@HOTMAIL.COM
# 5      ROBIN E SLACK      ROBERTSLACK008@YAHOO.COM
# 6   PHILLIP W MILLER       PHILMILLER0762@LIVE.COM
# 9    AYAD null HADAB           HADABAYAD@YAHOO.COM
# 11  FRONIA S SCHARCK    BLESSEDBEYOND.63@GMAIL.COM
#
#                                owner_Phone_Numbers  ownertwo_Full_Name  \
# 4                                       9032720984                 NaN
# 5   2818155643 DNC, 7135407553 DNC, 8323348380 DNC       DAVID R SLACK
# 6                   7134028392 DNC, 8327413421 DNC                 NaN
# 9                           7132910848, 7138256379  SAHAR ABDULHUSSEIN
# 11                                  2813458890 DNC                 NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 4                        NaN                     NaN
# 5                        NaN                     NaN
# 6                        NaN                     NaN
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'5633_BLUERIDGE_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#     owner_Full_Name     owner_email_Addresses  \
# 2   ARTHUR E ROZIER  ROZIERARTHUR52@YAHOO.COM
# 32    DAWN M BALLIS      DMBALLIS@COMCAST.NET
#
#                        owner_Phone_Numbers ownertwo_Full_Name  \
# 2                               7063662599   NIKOLE J POLLARD
# 32  6783602985 DNC, 6784938901, 6786348799                NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers             street  \
# 2   NIKOLE.POLLARD@YAHOO.COM            7.063933e+09      3708 13TH AVE
# 32                       NaN                     NaN  120 PROMINENCE CT
#
#         City      City State State  Zipcode Relationship_to_Property
# 2   COLUMBUS  COLUMBUS    GA    GA    31904         1336 WINIFRED LN
# 32  COLUMBUS    CANTON    GA    GA    30114        5620 BLUERIDGE DR

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'730_W_6TH_ST_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#      owner_Full_Name    owner_email_Addresses owner_Phone_Numbers  \
# 0   ROBERT L SCHERTZ       RSCHERUS@YAHOO.COM      5035127108 DNC
# 4     APRIL D MOSLEY       SASSYAPRIL@MSN.COM      2818182314 DNC
# 18   GRANT G SIEMENS  GKSIEMENS@SBCGLOBAL.NET      4799271396 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 0     SUZANNA SCHERTZ                       NaN                     NaN
# 4                 NaN                       NaN                     NaN
# 18  KIMBERLEE SIEMENS                       NaN                     NaN
#
#              street        City       City State State  Zipcode  \
# 0   2680 RIVER RD S  BOONEVILLE      SALEM    AR    OR    97302
# 4   24019 N 43RD DR  BOONEVILLE   GLENDALE    AR    AZ    85310
# 18   1278 PIAZZA RD  BOONEVILLE  TONTITOWN    AR    AR    72762
#
#    Relationship_to_Property
# 0              577 W 4TH ST
# 4                       NaN
# 18             538 W 6TH ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2515_3RD_AVE_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#     owner_Full_Name     owner_email_Addresses             owner_Phone_Numbers  \
# 15  VICKIE P THOMAS  T.VICTORIA3190@GMAIL.COM  3217271727 DNC, 3219607446 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 15    VICKIE P THOMAS                       NaN                     NaN
#
#                    street      City     City State State  Zipcode  \
# 15  1605 COUNTRY COVE CIR  PALM BAY  MALABAR    FL    FL  32950.0
#
#    Relationship_to_Property
# 15          2565 3RD AVE NE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1631_E_FERN_abs_Sheet1.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#          owner_Full_Name      owner_email_Addresses  \
# 1     CAREY G MACCONNELL            CSALLY1@AOL.COM
# 7        ALFRED H MILLER  SHELBYFUENTES77@GMAIL.COM
# 8   LINDSAY null ZELLNER  LINDSAY.ZELLNER@GMAIL.COM
# 14        FRANCIS A SMET      PLAINBLUE@VERIZON.NET
#
#                        owner_Phone_Numbers  ownertwo_Full_Name  \
# 1   8634093429, 8635590681, 8636475363 DNC  CAREY G MACCONNELL
# 7               4072979913, 8634504903 DNC                 NaN
# 8                           8634255045 DNC     JOSHUA G RIPLEY
# 14                          8636701388 DNC                 NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 1                        NaN                     NaN
# 7                        NaN                     NaN
# 8                        NaN                     NaN
# 14                       NaN                     NaN
#
#                        street      City      City State State  Zipcode  \
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1602_D_AVE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name   owner_email_Addresses  \
# 3   CHARLES W DYER  CHUCK.DYER@HOTMAIL.COM
# 8  BRENT D JOHNSON   BRENTDJOHNSON@ATT.NET
#
#                               owner_Phone_Numbers  ownertwo_Full_Name  \
# 3  7655295508 DNC, 7659321244 DNC, 8126143603 DNC                 NaN
# 8                                      3173712731                 NaN
#
#    ownertwo_email_Addresses  ownertwo_Phone_Numbers                    street  \
# 3                       NaN                     NaN  5565 N COUNTY ROAD 625 E
# 8                       NaN                     NaN            8787 SURREY DR
#
#          City       City State State  Zipcode Relationship_to_Property
# 3  NEW CASTLE  MOORELAND    IN    IN    47360                    D AVE
# 8  NEW CASTLE  PENDLETON    IN    IN    46064               1615 C AVE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'402_PERRY_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'4010_KENNYWOOD_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#   owner_Full_Name   owner_email_Addresses  \
# 7  ANDREA M LABIK  ALABIK@LAB-SERVICE.COM
#
#                           owner_Phone_Numbers ownertwo_Full_Name  \
# 7  3043423045 DNC, 3046101073, 4124611074 DNC                NaN
#
#    ownertwo_email_Addresses  ownertwo_Phone_Numbers        street  \
# 7                       NaN                     NaN  481 KEITH LN
#
#            City        City State State  Zipcode Relationship_to_Property
# 7  WEST MIFFLIN  WEST ISLIP    PA    NY    11795        3809 VISTAVIEW ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'4135_BARRON_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#   owner_Full_Name owner_email_Addresses     owner_Phone_Numbers  \
# 5    DALE W CATER      DALE5656@ATT.NET  9016805554, 9017447129
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 5       DALE W CATER                       NaN                     NaN
#
#            street     City     City State State  Zipcode  \
# 5  4452 QUINCE RD  MEMPHIS  MEMPHIS    TN    TN  38117.0
#
#   Relationship_to_Property
# 5        1316 OAK RIDGE DR

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'COUNTY_RD_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2410_SOUTHGATE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'63_WATERSEDGE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#      owner_Full_Name     owner_email_Addresses         owner_Phone_Numbers  \
# 3   STEFANI L HAZELL  STEVILYNNE2400@GMAIL.COM              7703550890 DNC
# 5   SHEDRICK L LACEY     S_CLEAVER@HOTMAIL.COM  6783840918, 7065890447 DNC
# 10    DENISE K JONES     DKJONES20@HOTMAIL.COM              7704595097 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 3                 NaN                       NaN                     NaN
# 5                 NaN                       NaN                     NaN
# 10                NaN                       NaN                     NaN
#
#                      street    City          City State State  Zipcode  \
# 3   2400 HUNTER AVE APT 10A  DALLAS         BRONX    GA    NY    10475
# 5          167 CHAMPION WAY  DALLAS         HIRAM    GA    GA    30141
# 10              PO BOX 1501  DALLAS  DOUGLASVILLE    GA    GA    30133
#
#    Relationship_to_Property
# 3         25 VILLA RIDGE DR
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1726_SE_169TH_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'130_DWIGHT_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#      owner_Full_Name    owner_email_Addresses owner_Phone_Numbers  \
# 12  KATHY M REISLING  MELISSAREISLING@MSN.COM      3308328715 DNC
#
#    ownertwo_Full_Name ownertwo_email_Addresses  \
# 12   OSCAR C REISLING  MELISSAREISLING@MSN.COM
#
#             ownertwo_Phone_Numbers        street       City       City State  \
# 12  3303091865 DNC, 3308328715 DNC  308 N 7TH ST  MASSILLON  CANNELTON    OH
#
#    State  Zipcode Relationship_to_Property
# 12    IN    47520        211 DWIGHT AVE SE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3521_SHIRLEY_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name owner_email_Addresses             owner_Phone_Numbers  \
# 10      LAC H PHAM   LACPHAM48@YAHOO.COM  4076446618 DNC, 4076950221 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 10        QUAN H PHAM                       NaN                     NaN
#
#                    street    City         City State State  Zipcode  \
# 10  1057 HOWELL HARBOR DR  APOPKA  CASSELBERRY    FL    FL    32707
#
#    Relationship_to_Property
# 10      1350 LAKE ASHER CIR

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'312_N_OAKLAND_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#        owner_Full_Name      owner_email_Addresses         owner_Phone_Numbers  \
# 18   JEANETTE S NETWAL      SPENCER1229@GMAIL.COM  3524605387, 3524606252 DNC
# 19  DANIEL E DEONARINE  DEONARINELEISHA@YAHOO.COM  3523659906, 3527026642 DNC
#
#     ownertwo_Full_Name ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 18                 NaN                      NaN                     NaN
# 19  VASHTI A DEONARINE    VELEUTICE96@GMAIL.COM                     NaN
#
#                        street      City            City State State  Zipcode  \
# 18  3408 S ATLANTIC AVE # 128  LEESBURG   DAYTONA BEACH    FL    FL    32118
# 19          1110 RIDGEWIND CT  LEESBURG  FRUITLAND PARK    FL    FL    34731
#
#    Relationship_to_Property
# 18            211 N MOSS ST
# 19            301 N MOSS ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2813_KESSLER_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#       owner_Full_Name    owner_email_Addresses         owner_Phone_Numbers  \
# 13  MICHELLE D HAWLEY     ERINH31990@YAHOO.COM                  4322126529
# 25     SUZANNE K HALE  SUZANNEHALE31@GMAIL.COM  4328898579, 4329341169 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 13                NaN                       NaN                     NaN
# 25  MICHAEL JOHN HALE                       NaN                     NaN
#
#                        street     City     City State State  Zipcode  \
# 13  1801 N MIDLAND DR APT 117  MIDLAND  MIDLAND    TX    TX    79707
# 25             2204 CULVER DR  MIDLAND  MIDLAND    TX    TX    79705
#
#    Relationship_to_Property
# 13       2810 ROOSEVELT AVE
# 25          2802 DELANO AVE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'4306_VANETTE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#         owner_Full_Name   owner_email_Addresses  \
# 1       YOLANDA F GILLS        YGILLS@YAHOO.COM
# 3  HERBERT J MCCULLOUGH       MCCM3I@SWBELL.NET
# 9     MARIA E HERNANDEZ  SARAMEJIA944@GMAIL.COM
#
#                   owner_Phone_Numbers ownertwo_Full_Name  \
# 1          2142984941, 2143375000 DNC       ELBERT GILLS
# 3  2143392117, 2143710503, 2145355280                NaN
# 9                          4696571088                NaN
#
#    ownertwo_email_Addresses  ownertwo_Phone_Numbers                   street  \
# 1                       NaN                     NaN  400 S ZANG BLVD STE 330
# 3                       NaN                     NaN            PO BOX 224075
# 9                       NaN                     NaN        210 E MAGNOLIA LN
#
#      City         City State State  Zipcode Relationship_to_Property
# 1  DALLAS       DALLAS    TX    TX    75208   4310 SOUTHERN HILLS DR
# 3  DALLAS       DALLAS    TX    TX    75222          4315 VANETTE LN
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'7942_SMITH_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3252_CHERRY_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name owner_email_Addresses  \
# 16  BRENT J WESTER  CAJUNSUE65@YAHOO.COM
#
#                        owner_Phone_Numbers ownertwo_Full_Name  \
# 16  4098338500, 4098409409 DNC, 4098669577                NaN
#
#    ownertwo_email_Addresses ownertwo_Phone_Numbers             street    City  \
# 16                      NaN                    NaN  3855 INVERNESS DR  GROVES
#
#         City State State  Zipcode Relationship_to_Property
# 16  BEAUMONT    TX    TX    77707                CHERRY ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2433_REID_OAKS_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#        owner_Full_Name    owner_email_Addresses  \
# 3        DANIEL A RUIZ   DARUIZ2004@HOTMAIL.COM
# 7       MELISSA D LINK  THECARLINKLLC@YAHOO.COM
# 10    MANIJEH null ABT     FRANKABT@HOTMAIL.COM
# 19  RACHELLE C KELLERT       BKELLERT@GMAIL.COM
#
#                            owner_Phone_Numbers ownertwo_Full_Name  \
# 3                                   5166983197       MARIA D RUIZ
# 7   7047245490 DNC, 7049077003 DNC, 9107889704                NaN
# 10              6617753765 DNC, 6618033518 DNC        FRANK G ABT
# 19                              2096069192 DNC    BRIAN J KELLERT
#
#    ownertwo_email_Addresses              ownertwo_Phone_Numbers  \
# 3    MALULURUIZ@HOTMAIL.COM  5166983197, 5166983617, 7047191783
# 7                       NaN                                 NaN
# 10                      NaN                                 NaN
# 19                      NaN                                 NaN
#
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'4806_LINBAR_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1217_PARKWAY_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'10544_WYNDCLIFF_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#   owner_Full_Name          owner_email_Addresses  \
# 3  STEVEN W MCGEE  STEVEN.WESLEY.MCGEE@GMAIL.COM
#
#                           owner_Phone_Numbers ownertwo_Full_Name  \
# 3  3218060378 DNC, 3219722108 DNC, 4076798752                NaN
#
#    ownertwo_email_Addresses  ownertwo_Phone_Numbers              street  \
# 3                       NaN                     NaN  6062 TWIN LAKES DR
#
#       City    City State State  Zipcode Relationship_to_Property
# 3  ORLANDO  OVIEDO    FL    FL    32765         10635 SUNTREE CT

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2427_JENSEN_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'4563_SUMMER_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name owner_email_Addresses owner_Phone_Numbers  \
# 9  CHANTI L CROSBY     FAXCELLCO@AOL.COM      9013790060 DNC
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 9                NaN                       NaN                     NaN
#
#              street     City     City State State  Zipcode  \
# 9  8867 WENHAM CV W  MEMPHIS  CORDOVA    TN    TN    38016
#
#   Relationship_to_Property
# 9        4567 SUMMER CRK N

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3758_STEAM_MILL_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#      owner_Full_Name   owner_email_Addresses         owner_Phone_Numbers  \
# 0  FELECIA C JOHNSON  FELECIAJOHNSON@ATT.NET  7063265759 DNC, 7066824997
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 0                NaN                       NaN                     NaN
#
#            street      City      City State State  Zipcode  \
# 0  347 HENSON AVE  COLUMBUS  COLUMBUS    GA    GA    31907
#
#   Relationship_to_Property
# 0         515 CLARADON AVE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'800_MAURY_ST_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#        owner_Full_Name    owner_email_Addresses  \
# 13  LAWRENCE O PERNELL  PERNELLSHELBY@GMAIL.COM
#
#                            owner_Phone_Numbers ownertwo_Full_Name  \
# 13  9012781017, 9013354715 DNC, 9013401020 DNC                NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers           street  \
# 13                       NaN                     NaN  357 N AVALON ST
#
#        City     City State State  Zipcode Relationship_to_Property
# 13  MEMPHIS  MEMPHIS    TN    TN    38112         1558 JACKSON AVE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'6374_38TH_AVE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2811_S_STORY_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#         owner_Full_Name        owner_email_Addresses  \
# 10      SANDRA L WARREN             GALEART2@AOL.COM
# 12  ROBERTA A BIBERDORF  ROBERTA_BIBERDORF@YAHOO.COM
# 13        EARL J TRAMEL     PHYLLIS.TRAMEL@GMAIL.COM
#
#            owner_Phone_Numbers ownertwo_Full_Name  ownertwo_email_Addresses  \
# 10              2147040706 DNC                NaN                       NaN
# 12  4696475580, 8172671919 DNC                NaN                       NaN
# 13              2143527986 DNC   PHYLLIS K TRAMEL  PHYLLIS.TRAMEL@GMAIL.COM
#
#                             ownertwo_Phone_Numbers           street    City  \
# 10                                             NaN    PO BOX 225683  IRVING
# 12                                             NaN  2102 MENARD HWY  IRVING
# 13  2143527986 DNC, 2145384525 DNC, 2149089439 DNC   944 FOXWOOD DR  IRVING
#
#       City State State  Zipcode Relationship_to_Property
# 10  DALLAS    TX    TX    75222           2824 SAGEBRUSH
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1860_KINNEY_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#       owner_Full_Name     owner_email_Addresses     owner_Phone_Numbers  \
# 0   TIFFINEY Z FOGGIE      TIFFINEY34@GMAIL.COM  5133023243, 5135121133
# 2  DESMOND null RILEY    DESMONDR@OPTONLINE.NET          5135045380 DNC
# 6  NICHOLAS M WINTERS  DARTHSIDIUS24430@AOL.COM  5138349540, 5138616195
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 0                 NaN                       NaN                     NaN
# 2                 NaN                       NaN                     NaN
# 6  NICHOLAS M WINTERS                       NaN                     NaN
#
#                street        City        City State State  Zipcode  \
# 0    5728 BELMONT AVE  CINCINNATI  CINCINNATI    OH    OH    45224
# 2    4801 KENNEDY AVE  CINCINNATI  CINCINNATI    OH    OH    45209
# 6  2752 QUEENSWOOD DR  CINCINNATI  CINCINNATI    OH    OH    45211
#
#   Relationship_to_Property
# 0          1828 KINNEY AVE
# 2          1915 KINNEY AVE
# 6            3236 WOLD AVE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'427_S_CLARA_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#        owner_Full_Name owner_email_Addresses     owner_Phone_Numbers  \
# 3    STEDROY J MAYNARD     STEDROY@YAHOO.COM  4072996270, 4076942346
# 13  BARRINGTON L DAMES    BDAMES@COMCAST.NET              2564570838
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 3                 NaN                       NaN                     NaN
# 13                NaN                       NaN                     NaN
#
#                  street    City        City State State  Zipcode  \
# 3    6500 W COLONIAL DR  DELAND     ORLANDO    FL    FL    32818
# 13  1601 SPARKMAN DR NW  DELAND  HUNTSVILLE    FL    AL    35816
#
#    Relationship_to_Property
# 3           403 S CLARA AVE
# 13        433 S PARSONS AVE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1970_OLD_CONCORD_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#         owner_Full_Name   owner_email_Addresses  \
# 0         TANYA R MOSES  129MOSES.SR1@GMAIL.COM
# 1  RANDOLPH null HARRIS      ZENDOG57@GMAIL.COM
# 4      NETTIE R DENISON       HUNT1JE@YAHOO.COM
#
#                           owner_Phone_Numbers ownertwo_Full_Name  \
# 0  6784133834 DNC, 6784133845 DNC, 7702854308                NaN
# 1                  7702854244, 7703885670 DNC                NaN
# 4                              6786257406 DNC                NaN
#
#    ownertwo_email_Addresses  ownertwo_Phone_Numbers                street  \
# 0                       NaN                     NaN      1322 EARLE CT SE
# 1                       NaN                     NaN  6364 COUNTY ROAD 388
# 4                       NaN                     NaN  250 JOHNSON RIVER RD
#
#         City       City State State  Zipcode Relationship_to_Property
# 0  COVINGTON    CONYERS    GA    GA    30013               105 IVY DR
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3205_BONNIE_BRAE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name   owner_email_Addresses owner_Phone_Numbers  \
# 16   JUAN M SUAREZ  JUANSUAREZ73@GMAIL.COM      6825584949 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 16                NaN                       NaN                     NaN
#
#                     street        City   City State State  Zipcode  \
# 16  1624 CAMPUS DR APT 151  FORT WORTH  HURST    TX    TX    76054
#
#    Relationship_to_Property
# 16        3301 TOM ELLEN ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1123_S_REMBERT_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#   owner_Full_Name owner_email_Addresses  owner_Phone_Numbers  \
# 8   CIMONE D BEAL  CIMONE1030@GMAIL.COM         9.016439e+09
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 8                NaN                       NaN                     NaN
#
#              street     City     City State State  Zipcode  \
# 8  3051 JOHNSON AVE  MEMPHIS  MEMPHIS    TN    TN    38112
#
#   Relationship_to_Property
# 8        1147 S REMBERT ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'625_EMPRESS_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#           owner_Full_Name       owner_email_Addresses owner_Phone_Numbers  \
# 17  GLENDA M WEATHERSPOON  GLENDA.WEATHERSPOO@ATT.NET      7065680564 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 17                NaN                       NaN                     NaN
#
#                     street      City  City State State  Zipcode  \
# 17  25307 BRIGHT HOLLOW LN  COLUMBUS  KATY    GA    TX    77494
#
#    Relationship_to_Property
# 17           2143 HUNTER CT

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1091_CHRISTOPHER_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#          owner_Full_Name     owner_email_Addresses  \
# 0           EZELL A LONG     EZELLLONG16@GMAIL.COM
# 1           VICKY E KERR        CELIAK@HOTMAIL.COM
# 17  ROBERT B KIRKPATRICK       BOBORCESQ@GMAIL.COM
# 21     SANDRA P CORNWELL  SANDRACORNWELL@YAHOO.COM
# 30       MARY J MCDANIEL         MARYMCD@GMAIL.COM
#
#                owner_Phone_Numbers ownertwo_Full_Name  \
# 0                       8033291259                NaN
# 1                   8033244807 DNC                NaN
# 17  8033278001 DNC, 8035174507 DNC                NaN
# 21                      8033244559                NaN
# 30                      8033472403                NaN
#
#    ownertwo_email_Addresses ownertwo_Phone_Numbers                    street  \
# 0                       NaN                    NaN              PO BOX 11231
# 1                       NaN                    NaN              PO BOX 11788
# 17                      NaN                    NaN     7665 MATT PT APT 1822
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'527_PARKDALE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name  owner_email_Addresses  \
# 15   BRYAN A WHITE   BRYAN925@HOTMAIL.COM
# 29   SHARON X ZHAO   SHARONZHAO@GMAIL.COM
# 34   ERIN S BAGLEY  ERINSBAGLEY@GMAIL.COM
#
#                                owner_Phone_Numbers ownertwo_Full_Name  \
# 15                  5122805682 DNC, 5127995682 DNC                NaN
# 29  5123290356 DNC, 5125896058 DNC, 5127051395 DNC        RUOSHU CHEN
# 34                                  8316884726 DNC                NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers                street  \
# 15                       NaN                     NaN      9205 LAURALAN DR
# 29                       NaN                     NaN  3009 MARAVILLAS LOOP
# 34                       NaN                     NaN       3416 VINTON AVE
#
#           City         City State State  Zipcode Relationship_to_Property
# 15  SAN MARCOS       AUSTIN    TX    TX    78736       411 CANDLELIGHT LN
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'107_RIFLE_RANGE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name owner_email_Addresses owner_Phone_Numbers  \
# 9  GLORIA D WILSON  SMITHKL4@HOTMAIL.COM      8644264212 DNC
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 9                NaN                       NaN                     NaN
#
#                   street   City   City State State  Zipcode  \
# 9  213 SUNDAY SILENCE LN  UNION  ELGIN    SC    SC    29045
#
#   Relationship_to_Property
# 9            128 POWELL ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'nearby_9052_Sterling-_673.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#              owner_Full_Name      owner_email_Addresses  \
# 0              EMONI C MAHDI     ALEXAMAHDI96@GMAIL.COM
# 1      ELIZABETH null ROMERO           JEDR@HOTMAIL.COM
# 7           SHIRLEY G WATSON             SW4048@ATT.COM
# 8            TIFFANY D SCOTT       TSCOTT3583@YAHOO.COM
# 15          TERESA J JOHNSON  JOHNSONTERESA25@YAHOO.COM
# ..                       ...                        ...
# 652  MATTHEW null HUTCHERSON         MADMATT3@YAHOO.COM
# 654          ALICIA J TAYLOR   YOUMUSTHAVEFAITH@AOL.COM
# 656          ANGELA C BLANKS       BIGRODCP28@YAHOO.COM
# 660             TONIA D TATE        EDUKTORTATE@MSN.COM
# 663         JAMES R SHEBESTA           JZEETS@GMAIL.COM
#
#                             owner_Phone_Numbers       ownertwo_Full_Name  \
# 0                                    5107258168  JEANETTE WALKER-JOHNSON
# 1                                4049366128 DNC         ROSA null ROMERO
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'226_E_1ST_ST_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name owner_email_Addresses  \
# 0   ALEX H AGUILAR  AAGUILARJR@GMAIL.COM
# 15    BILLY R LOTT     BILLYLOTT@ATT.NET
#
#                            owner_Phone_Numbers  ownertwo_Full_Name  \
# 0   7046540772 DNC, 8324704246, 8326606743 DNC  VERONICA S AGUILAR
# 15                  8322627039, 8325451885 DNC                 NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers               street  \
# 0                        NaN            8.324704e+09  3129 AUTUMN LEAF DR
# 15                       NaN                     NaN         11101 N P ST
#
#          City         City State State  Zipcode Relationship_to_Property
# 0   DEER PARK  FRIENDSWOOD    TX    TX    77546             221 E 4TH ST
# 15  DEER PARK     LA PORTE    TX    TX    77571             205 E 1ST ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'409_N_STATE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#        owner_Full_Name owner_email_Addresses owner_Phone_Numbers  \
# 3  ISSELLE null MEDINA      IMEDI004@FIU.EDU      3059232697 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 3                 NaN                       NaN                     NaN
#
#            street          City   City State State  Zipcode  \
# 3  2291 NW 1ST ST  INDIANAPOLIS  MIAMI    IN    FL    33125
#
#   Relationship_to_Property
# 3         339 N WALCOTT ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'119_BIRMINGHAM_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#     owner_Full_Name   owner_email_Addresses  \
# 4      MARIA A PENA     MPENA2426@GMAIL.COM
# 10    MARY A WARREN  MARYWARREN21@GMAIL.COM
# 13  FELICITA S HENN  SALLY_81GA@HOTMAIL.COM
#
#                    owner_Phone_Numbers   ownertwo_Full_Name  \
# 4   6093841365, 6095983020, 8632104141                  NaN
# 10                      9178160518 DNC                  NaN
# 13                          4076926639  PATRICIA null BOSCH
#
#       ownertwo_email_Addresses  ownertwo_Phone_Numbers              street  \
# 4                          NaN                     NaN  2206 DEER CREEK DR
# 10                         NaN                     NaN      405 SPANGLE DR
# 13  DRAPATRICIABOSCH@GMAIL.COM                     NaN        PO BOX 25577
#
#          City           City State State Zipcode Relationship_to_Property
# 4   KISSIMMEE     PLAINSBORO    FL    NJ   08536        119 WHITEHALL WAY
# 10  KISSIMMEE  NORTH BABYLON    FL    NY   11703        175 BIRMINGHAM DR
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2124_WISTERIA_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#          owner_Full_Name owner_email_Addresses  \
# 8   FREDERICK J OPPLIGER   SPSCOUTER@GMAIL.COM
# 12     SUZANNE G GLASGOW       SGG3384@AOL.COM
#
#                            owner_Phone_Numbers  ownertwo_Full_Name  \
# 8               7273430680 DNC, 7277813978 DNC                 NaN
# 12  3369222179, 9102283534 DNC, 9103996625 DNC                 NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers         street  \
# 8                        NaN                     NaN   PO BOX 13623
# 12                       NaN                     NaN  104 E BANK RD
#
#           City              City State State  Zipcode Relationship_to_Property
# 8   WILMINGTON  SAINT PETERSBURG    NC    FL    33733         2130 WISTERIA DR
# 12  WILMINGTON        WILMINGTON    NC    NC    28412         2119 WISTERIA DR

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'32_SPRINGBROOK_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name   owner_email_Addresses         owner_Phone_Numbers  \
# 8  SARAH J DOHERTY  RENEEZAGER@NETZERO.NET  2055566873 DNC, 7168166895
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 8                NaN                       NaN                     NaN
#
#             street        City        City State State  Zipcode  \
# 8  47 CHEROKEE HLS  TUSCALOOSA  TUSCALOOSA    AL    AL    35404
#
#   Relationship_to_Property
# 8           21 SPRINGBROOK

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'618_COLFAX_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#         owner_Full_Name owner_email_Addresses     owner_Phone_Numbers  \
# 2     MICHAEL W ASSELIN      HUGER392@AOL.COM          6035719603 DNC
# 4  ANTHONY S RANGASAMMY      MARLO713@AOL.COM  3864416356, 3865061196
# 9    RONALD L PATTERSON   BIGPAT819@YAHOO.COM          3864053273 DNC
#
#            ownertwo_Full_Name  ownertwo_email_Addresses  \
# 2                         NaN                       NaN
# 4          JASODRA RANGASAMMY                       NaN
# 9  STEPHANIE M BELL-PATTERSON                       NaN
#
#    ownertwo_Phone_Numbers             street           City           City  \
# 2                     NaN         PO BOX 392  DAYTONA BEACH         NASHUA
# 4                     NaN      145 DIANNE DR  DAYTONA BEACH   ORMOND BEACH
# 9                     NaN  1046 BERKSHIRE RD  DAYTONA BEACH  DAYTONA BEACH
#
#   State State  Zipcode Relationship_to_Property
# 2    FL    NH     3061      607 WESTMORELAND RD
# 4    FL    FL    32176            1092 NORTH ST
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1014_EDEN_ST_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#       owner_Full_Name   owner_email_Addresses owner_Phone_Numbers  \
# 9  DOLORES H THOMPSON  TOURSAVANNAH@GMAIL.COM      9122362997 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 9  DOLORES H THOMPSON                       NaN                     NaN
#
#                    street      City     City State State  Zipcode  \
# 9  1307 CENTRAL CHURCH RD  COLUMBUS  MIDLAND    GA    GA    31820
#
#   Relationship_to_Property
# 9           8400 CANAAN DR

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3120_KIMBALL_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#   owner_Full_Name owner_email_Addresses         owner_Phone_Numbers  \
# 3  LAURA D MILLER      CA5142@YAHOO.COM  8166329200 DNC, 8168626733
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 3                NaN                       NaN                     NaN
#
#           street         City         City State State  Zipcode  \
# 3  827 N 54TH ST  KANSAS CITY  KANSAS CITY    KS    KS    66102
#
#   Relationship_to_Property
# 3         3244 WEBSTER AVE

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'5938_BUXTON_DR_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#         owner_Full_Name    owner_email_Addresses  \
# 3   CATRINA Y BIRCHETTE   CATRINA904@HOTMAIL.COM
# 12       TAURUS D DAVIS   DAVIS.TAURUS@YAHOO.COM
# 16   JEMEKIA M THORNTON    JEMEKIA@BELLSOUTH.NET
# 19       EBONY N MARTIN  NULUVNULIFE@HOTMAIL.COM
#
#                owner_Phone_Numbers ownertwo_Full_Name  \
# 3                       4348480384                NaN
# 12  2027102619 DNC, 7572184139 DNC                NaN
# 16                  7704693651 DNC                NaN
# 19                      7065074727                NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 3                        NaN                     NaN
# 12                       NaN                     NaN
# 16                       NaN                     NaN
# 19                       NaN                     NaN
#
#                               street      City              City State State  \
# 3   1031 ASHLEY STATION BLVD APT 301  COLUMBUS          COLUMBUS    GA    GA
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3372_TWO_SISTERS_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#         owner_Full_Name   owner_email_Addresses  \
# 17  LASHONDA T IDLEBIRD  LASHONDAID@HOTMAIL.COM
#
#                owner_Phone_Numbers  ownertwo_Full_Name  \
# 17  7578718952 DNC, 8504567051 DNC  SHANNON D IDLEBIRD
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers             street  \
# 17                       NaN                     NaN  3836 AFFIRMED WAY
#
#          City            City State State  Zipcode Relationship_to_Property
# 17  PENSACOLA  VIRGINIA BEACH    FL    VA    23456     3404 TWO SISTERS WAY

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'21459_NORTH_ST_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#              owner_Full_Name      owner_email_Addresses  \
# 2            JUAN A CASTILLO        BADGAVIN1@GMAIL.COM
# 5        MARTIN H SPOONEMORE     JOPRETTE@SBCGLOBAL.NET
# 15          ROLMAN M AGUILAR  ROLMANAGUILAR18@GMAIL.COM
# 18          MARY H NICHOLSON      ANNHAS92140@YAHOO.COM
# 27  FERNANDO null VALENZUELA        JSMILEZ31@GMAIL.COM
#
#                    owner_Phone_Numbers   ownertwo_Full_Name  \
# 2                           5628649901                  NaN
# 5   7136916218, 7136992663, 8322506302  MARTIN H SPOONEMORE
# 15              2813544871, 8323597746                  NaN
# 18      7133979434 DNC, 7134536976 DNC                  NaN
# 27      8322578772 DNC, 8327175829 DNC                  NaN
#
#     ownertwo_email_Addresses  ownertwo_Phone_Numbers                   street  \
# 2                        NaN                     NaN       1923 LAUREL BAY DR
# 5                        NaN                     NaN    18606 WALDEN GLEN CIR
# ...

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2860_DOGWOOD_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#     owner_Full_Name owner_email_Addresses                 owner_Phone_Numbers  \
# 3  ANA null CANALES    SARAC726@YAHOO.COM  6782216605, 6784143486, 6788581079
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 3    DOUGLAS CANALES                       NaN                     NaN
#
#                  street    City           City State State  Zipcode  \
# 3  875 ASHLAND PARK WAY  DULUTH  LAWRENCEVILLE    GA    GA    30045
#
#   Relationship_to_Property
# 3               DULUTH HWY

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'1206_13TH_AVE_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#       owner_Full_Name      owner_email_Addresses owner_Phone_Numbers  \
# 10  SAKITA L TRAMMELL  SAKITA_TRAMMELL@YAHOO.COM      7067735050 DNC
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 10                NaN                       NaN                     NaN
#
#                        street    City          City State State  Zipcode  \
# 10  4600 SPRINGWATER CT APT K  LANETT  OWINGS MILLS    AL    MD    21117
#
#    Relationship_to_Property
# 10            822 S 11TH ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'740_STILTON_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#          owner_Full_Name     owner_email_Addresses  owner_Phone_Numbers  \
# 2  DEMETRI null LOCKHART  DARICHARDSON57@GMAIL.COM         8.033787e+09
#
#   ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 2                NaN                       NaN                     NaN
#
#        street        City        City State State  Zipcode  \
# 2  PO BOX 613  ORANGEBURG  ORANGEBURG    SC    SC    29116
#
#   Relationship_to_Property
# 2               STILTON RD

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'4345_WALTON_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#       owner_Full_Name owner_email_Addresses  owner_Phone_Numbers  \
# 0  SHIRLEY B MCFADDEN        LILP1@MAIL.COM         8.433081e+09
#
#    ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 0                 NaN                       NaN                     NaN
#
#                  street              City         City State State  Zipcode  \
# 0  9103 FIELDSTONE TRCE  NORTH CHARLESTON  SUMMERVILLE    SC    SC  29485.0
#
#   Relationship_to_Property
# 0           4351 WALTON ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2518_S_HOLT_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#     owner_Full_Name     owner_email_Addresses  \
# 6  KIMBERLY M SAURO  KSAURO@SKINCEUTICALS.COM
# 7      AVERY J DYER          DLJD91@YAHOO.COM
#
#                               owner_Phone_Numbers ownertwo_Full_Name  \
# 6  3152639026 DNC, 3156226662 DNC, 8043497110 DNC                NaN
# 7                                  3174427453 DNC                NaN
#
#    ownertwo_email_Addresses  ownertwo_Phone_Numbers          street  \
# 6                       NaN                     NaN  8805 W 30TH ST
# 7                       NaN                     NaN   6705 DORIS DR
#
#            City          City State State  Zipcode Relationship_to_Property
# 6  INDIANAPOLIS  INDIANAPOLIS    IN    IN    46234        2550 S MCCLURE ST
# 7  INDIANAPOLIS  INDIANAPOLIS    IN    IN    46214        2503 S MCCLURE ST

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2377_SANS_SOUCI_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#      owner_Full_Name owner_email_Addresses owner_Phone_Numbers  \
# 3  LUKE null KNIZLEY    LKNIZLEY@GMAIL.COM      2514584833 DNC
#
#     ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 3  KEITH LOREN KNIZLEY                       NaN                     NaN
#
#               street    City    City State State  Zipcode  \
# 3  1058 HILLCREST LN  MOBILE  MOBILE    AL    AL    36693
#
#   Relationship_to_Property
# 3        2358 N OCTAVIA DR

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'427_CYPRESS_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3607_WALLWERTH_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
#    owner_Full_Name   owner_email_Addresses         owner_Phone_Numbers  \
# 17   ETHAN M DUGAN  DUGANETHAN@HOTMAIL.COM  2162780287, 4196861245 DNC
#
#         ownertwo_Full_Name  ownertwo_email_Addresses  ownertwo_Phone_Numbers  \
# 17  KIMBERLYORSURVTC DUGAN                       NaN                     NaN
#
#               street    City     City State State  Zipcode  \
# 17  10307 PORTAGE RD  TOLEDO  PORTAGE    OH    OH    43451
#
#    Relationship_to_Property
# 17          3628 JACKMAN RD

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'2976_CHURCH_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []

# %%
import pandas
import pandas as pd
df = pd.read_csv(r'3520_REVERE_DR_abs.csv')
df
df.rename(columns={"Owner 1 Full Name": "owner_Full_Name"}, inplace=True)
df.rename(columns={"Owner 1 Email Addresses": "owner_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 1 Phone Numbers": "owner_Phone_Numbers"}, inplace=True)
df.rename(columns={"Owner 2 Full Name": "ownertwo_Full_Name"}, inplace=True)
df.rename(columns={"Owner 2 Email Addresses": "ownertwo_email_Addresses"}, inplace=True)
df.rename(columns={"Owner 2 Phone Numbers": "ownertwo_Phone_Numbers"}, inplace=True)
df.rename(columns={"Mailing Address": "street"}, inplace=True)
df.rename(columns={"Mailing City": "City"}, inplace=True)
df.rename(columns={"Mailing State": "State"}, inplace=True)
df.rename(columns={"Mailing ZIP 5": "Zipcode"}, inplace=True)
df.rename(columns={"Property Address": "Relationship_to_Property"}, inplace=True)
df
new=df[['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers','ownertwo_Full_Name', 'ownertwo_email_Addresses','ownertwo_Phone_Numbers','street','City','State','Zipcode','Relationship_to_Property']]
new
new.dropna(subset=['owner_Full_Name', 'owner_email_Addresses','owner_Phone_Numbers'])
# Out:
# Empty DataFrame
# Columns: [owner_Full_Name, owner_email_Addresses, owner_Phone_Numbers, ownertwo_Full_Name, ownertwo_email_Addresses, ownertwo_Phone_Numbers, street, City, City, State, State, Zipcode, Relationship_to_Property]
# Index: []
